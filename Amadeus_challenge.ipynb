# %% [markdown]
# # Amadeus challenge

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# ### Con consola

# %%
! pwd
# Out:
# /home/dsc/Data/challenge

# %%
! bzcat ./bookings_sample.csv.bz2 | wc -l
# Out:
# 10000

# %%
! ls
# Out:
# bookings.csv.bz2	 searches.csv.bz2	   Untitled.ipynb
# bookings_sample.csv.bz2  searches_samples.csv.bz2

# %%
! bzcat ./searches_samples.csv.bz2 | wc -l
# Out:
# 10000

# %% [markdown]
# ### Con pyhon

# %% [markdown]
# ### Con Pandas se queda colgado!!

# %%
import bz2 as bz2

# %%
filename = './bookings_sample.csv.bz2'
fileBZ2=bz2.BZ2File(filename)

# %%
type(fileBZ2)
# Out:
# bz2.BZ2File

# %%
count = 0
for f in fileBZ2:
    count=count+1

count
# Out:
# 10000

# %%
content
# Out:
# b''

# %%
! ls
# Out:
# bookings.csv.bz2	 searches.csv.bz2	   Untitled.ipynb
# bookings_sample.csv.bz2  searches_samples.csv.bz2

# %% [markdown]
# ### usando fichero descomprimido

# %%
filename='./bookings_sample.csv'
with open(filename, "r") as file_input:
    k=0
    for line in file_input:
        k+=1
k
# Out:
# 10000

# %% [markdown]
# ## Execise 2

# %%
pwd
# Out:
# '/home/dsc/Data/challenge'

# %%
! ls
# Out:
# bookings.csv.bz2     bookings_sample.csv.bz2  searches_samples.csv.bz2
# bookings_sample.csv  searches.csv.bz2	      Untitled.ipynb

# %%
import pandas as pd

# %%
#don't do this!!!
#b = pd.read_csv('bookings.csv.bz2', sep='^')

# %%
b = pd.read_csv('bookings.csv.bz2', sep='^', nrows=10000)

# %%
b
# Out:
#       act_date             source  pos_ctry                          pos_iata  \
# 0     2013-03-05 00:00:00  1A      DE        a68dd7ae953c8acfb187a1af2dcbe123
# 1     2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 2     2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 3     2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 4     2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 5     2013-03-20 00:00:00  1V      US        0283592e45e392871f7e14b1e22a9aaf
# 6     2013-03-20 00:00:00  1V      US        0283592e45e392871f7e14b1e22a9aaf
# 7     2013-03-25 00:00:00  1V      JP        5af045902bd23cab579915611d99e1e0
# 8     2013-03-25 00:00:00  1V      JP        5af045902bd23cab579915611d99e1e0
# 9     2013-03-25 00:00:00  1V      JP        5af045902bd23cab579915611d99e1e0
# 10    2013-03-25 00:00:00  1V      JP        5af045902bd23cab579915611d99e1e0
# ...

# %%
b.head()
# Out:
#    act_date             source  pos_ctry                          pos_iata  \
# 0  2013-03-05 00:00:00  1A      DE        a68dd7ae953c8acfb187a1af2dcbe123
# 1  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 2  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 3  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 4  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
#
#                           pos_oid                      rloc            \
# 0  1a11ae49fcbf545fd2afc1a24d88d2b7  ea65900e72d71f4626378e2ebd298267
# 1  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 2  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 3  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
# 4  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
#
#    cre_date             duration  distance  dep_port    ...      \
# ...

# %%
b.columns
# Out:
# Index(['act_date           ', 'source', 'pos_ctry', 'pos_iata', 'pos_oid  ',
#        'rloc          ', 'cre_date           ', 'duration', 'distance',
#        'dep_port', 'dep_city', 'dep_ctry', 'arr_port', 'arr_city', 'arr_ctry',
#        'lst_port', 'lst_city', 'lst_ctry', 'brd_port', 'brd_city', 'brd_ctry',
#        'off_port', 'off_city', 'off_ctry', 'mkt_port', 'mkt_city', 'mkt_ctry',
#        'intl', 'route          ', 'carrier', 'bkg_class', 'cab_class',
#        'brd_time           ', 'off_time           ', 'pax', 'year', 'month',
#        'oid      '],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
b.sample(5)
# Out:
#       act_date             source  pos_ctry                          pos_iata  \
# 4394  2013-03-07 00:00:00  1V      US        e7b82bdf42b5eff201343e1005b924e7
# 8655  2013-03-12 00:00:00  1A      UA        eb38e98871141cc74056083d00665bee
# 8641  2013-03-11 00:00:00  1A      NG        f2e12e4e2b174c4e7cbde6d03ba867c6
# 6762  2013-03-07 00:00:00  1V      US        254ec21001bbfe5a0f02057351d624fd
# 3987  2013-03-22 00:00:00  1P      US        83ccf07a55606976f78e63fcc805f58c
#
#                              pos_oid                      rloc            \
# 4394  8ec7b6135d40dd2052baccff0907afc8  6a488e16b85d230638d9e21a8baab40d
# 8655  c44d9fa715c4e7f31a296bd4ed504f65  35e2d2697c046a320cf40d54ee908172
# 8641  98292ebbf9b68f322a44674bb6f8e5b1  054d1757d0a271c9cf0af75c604dbd47
# 6762  e028c558a1b45b1a732853b36de45837  9971992d780535e9037628ec60dd53b4
# 3987  1490c3c5f95f04fa076fe15c775a80a9  674ac42019d880fde3a29a3561fa3371
#
# ...

# %%
b.count()
# Out:
# act_date               10000
# source                 10000
# pos_ctry               10000
# pos_iata               10000
# pos_oid                10000
# rloc                   10000
# cre_date               10000
# duration               10000
# distance               10000
# dep_port               10000
# dep_city               10000
# dep_ctry               10000
# arr_port               10000
# arr_city               10000
# arr_ctry               10000
# lst_port               10000
# lst_city               10000
# lst_ctry               10000
# brd_port               10000
# brd_city               10000
# brd_ctry               10000
# off_port               10000
# off_city               10000
# off_ctry               10000
# mkt_port               10000
# mkt_city               10000
# mkt_ctry               10000
# intl                   10000
# route                  10000
# carrier                10000
# bkg_class              10000
# cab_class              10000
# ...

# %%
b.describe()
# Out:
#             duration      distance          intl           pax     year  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.0
# mean    20209.543000    455.563300      0.596300      0.516300   2013.0
# std     42241.125937   1738.810081      0.490663      1.783943      0.0
# min        59.000000      0.000000      0.000000    -25.000000   2013.0
# 25%      3339.000000      0.000000      0.000000     -1.000000   2013.0
# 50%      7734.500000      0.000000      1.000000      1.000000   2013.0
# 75%     19077.000000      0.000000      1.000000      1.000000   2013.0
# max    488131.000000  18481.000000      1.000000     25.000000   2013.0
#
#          month
# count  10000.0
# mean       3.0
# std        0.0
# min        3.0
# 25%        3.0
# 50%        3.0
# 75%        3.0
# max        3.0

# %%
b.shape
# Out:
# (10000, 38)

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 38 columns):
# act_date               10000 non-null object
# source                 10000 non-null object
# pos_ctry               10000 non-null object
# pos_iata               10000 non-null object
# pos_oid                10000 non-null object
# rloc                   10000 non-null object
# cre_date               10000 non-null object
# duration               10000 non-null int64
# distance               10000 non-null int64
# dep_port               10000 non-null object
# dep_city               10000 non-null object
# dep_ctry               10000 non-null object
# arr_port               10000 non-null object
# arr_city               10000 non-null object
# arr_ctry               10000 non-null object
# lst_port               10000 non-null object
# lst_city               10000 non-null object
# lst_ctry               10000 non-null object
# ...

# %%
list(b.columns)
# Out:
# ['act_date           ',
#  'source',
#  'pos_ctry',
#  'pos_iata',
#  'pos_oid  ',
#  'rloc          ',
#  'cre_date           ',
#  'duration',
#  'distance',
#  'dep_port',
#  'dep_city',
#  'dep_ctry',
#  'arr_port',
#  'arr_city',
#  'arr_ctry',
#  'lst_port',
#  'lst_city',
#  'lst_ctry',
#  'brd_port',
#  'brd_city',
#  'brd_ctry',
#  'off_port',
#  'off_city',
#  'off_ctry',
#  'mkt_port',
#  'mkt_city',
#  'mkt_ctry',
#  'intl',
#  'route          ',
#  'carrier',
#  'bkg_class',
#  'cab_class',
#  'brd_time           ',
#  'off_time           ',
#  'pax',
#  'year',
#  'month',
#  'oid      ']

# %%
len(b.columns)
# Out:
# 38

# %%
b.columns = ['act_date',
 'source',
 'pos_ctry',
 'pos_iata',
 'pos_oid',
 'rloc',
 'cre_date',
 'duration',
 'distance',
 'dep_port',
 'dep_city',
 'dep_ctry',
 'arr_port',
 'arr_city',
 'arr_ctry',
 'lst_port',
 'lst_city',
 'lst_ctry',
 'brd_port',
 'brd_city',
 'brd_ctry',
 'off_port',
 'off_city',
 'off_ctry',
 'mkt_port',
 'mkt_city',
 'mkt_ctry',
 'intl',
 'route',
 'carrier',
 'bkg_class',
 'cab_class',
 'brd_time',
 'off_time',
 'pax',
 'year',
 'month',
 'oid']

# %%
b.columns
# Out:
# Index(['act_date', 'source', 'pos_ctry', 'pos_iata', 'pos_oid', 'rloc',
#        'cre_date', 'duration', 'distance', 'dep_port', 'dep_city', 'dep_ctry',
#        'arr_port', 'arr_city', 'arr_ctry', 'lst_port', 'lst_city', 'lst_ctry',
#        'brd_port', 'brd_city', 'brd_ctry', 'off_port', 'off_city', 'off_ctry',
#        'mkt_port', 'mkt_city', 'mkt_ctry', 'intl', 'route', 'carrier',
#        'bkg_class', 'cab_class', 'brd_time', 'off_time', 'pax', 'year',
#        'month', 'oid'],
#       dtype='object')

# %%
b
# Out:
#                  act_date  source  pos_ctry                          pos_iata  \
# 0     2013-03-05 00:00:00  1A      DE        a68dd7ae953c8acfb187a1af2dcbe123
# 1     2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 2     2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 3     2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 4     2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 5     2013-03-20 00:00:00  1V      US        0283592e45e392871f7e14b1e22a9aaf
# 6     2013-03-20 00:00:00  1V      US        0283592e45e392871f7e14b1e22a9aaf
# 7     2013-03-25 00:00:00  1V      JP        5af045902bd23cab579915611d99e1e0
# 8     2013-03-25 00:00:00  1V      JP        5af045902bd23cab579915611d99e1e0
# 9     2013-03-25 00:00:00  1V      JP        5af045902bd23cab579915611d99e1e0
# 10    2013-03-25 00:00:00  1V      JP        5af045902bd23cab579915611d99e1e0
# ...

# %%
b.columns = b.columns.str.strip()

# %%
bb = b[['arr_port', 'pax','act_date']]

# %%
bb.groupby('arr_port')

# %% [markdown]
# ### Juntamos todos los comandos que sabemos que funcionan para tenerlos en una sola celda

# %%
import pandas as pd
b = pd.read_csv('bookings_sample.csv.bz2', sep='^', usecols=['arr_port', 'pax','year'] ,nrows=10000)
b.columns = b.columns.str.strip()
b= b.dropna()
b =b[b['year']==2013]
b = b[['arr_port','pax']]
b = b.groupby('arr_port').sum()
b = b.sort_values('pax', ascending=False)
b = b.head(10)
b
# Out:
#           pax
# arr_port
# HKG       112
# LGA        95
# ORD        94
# JFK        92
# LAX        91
# SFO        91
# MCO        90
# DCA        82
# DEN        79
# LHR        76

# %% [markdown]
# ### Ahora vamos a iterar sobre el fichero para hacer el procesamiento completo

# %%
b = pd.read_csv('bookings_sample.csv.bz2', sep='^', usecols=['arr_port', 'pax','year'] , chunksize=1000)

# %%
type(b)
# Out:
# pandas.io.parsers.TextFileReader

# %%
b0=next(b)

# %%
type(b0)
# Out:
# pandas.core.frame.DataFrame

# %%
b0.shape
# Out:
# (1000, 3)

# %%
b = pd.read_csv('bookings_sample.csv.bz2', sep='^', usecols=['arr_port', 'pax','year'] , chunksize=1000)
for i, chunk in enumerate(b):
    print(chunk.head())
    print("---------------")
    if i==3:
        break
# Out:
#    arr_port  pax  year
# 0  LHR        -1  2013
# 1  CLT         1  2013
# 2  CLT         1  2013
# 3  SVO         1  2013
# 4  SVO         1  2013
# ---------------
#       arr_port  pax  year
# 1000  TPE         3  2013
# 1001  TPE         3  2013
# 1002  TPE        -3  2013
# 1003  TPE         3  2013
# 1004  TPE        -3  2013
# ---------------
#       arr_port  pax  year
# 2000  LHE         1  2013
# 2001  HBE        -1  2013
# 2002  HBE         1  2013
# 2003  HBE        -1  2013
# 2004  ICN        -1  2013
# ---------------
#       arr_port  pax  year
# 3000  DEN         1  2013
# 3001  LAX         1  2013
# 3002  LAX         1  2013
# 3003  BUF         2  2013
# 3004  PVG         1  2013
# ---------------

# %%
bc = pd.read_csv('bookings.csv.bz2', sep='^', usecols=['arr_port', 'pax','year'] , chunksize=1000000)

sum_all_chunks=pd.DataFrame()
for i, chunk in enumerate(bc):
    b= chunk.dropna()
    b =b[b['year']==2013]
    b = b[['arr_port','pax']]
    b = b.groupby('arr_port').sum()
    sum_all_chunks = sum_all_chunks.append(b)

total  = sum_all_chunks.groupby('arr_port').sum()
total = total.sort_values('pax', ascending=False)
total = total.head(10)
total
# Out:
#               pax
# arr_port
# LHR       88809.0
# MCO       70930.0
# LAX       70530.0
# LAS       69630.0
# JFK       66270.0
# CDG       64490.0
# BKK       59460.0
# MIA       58150.0
# SFO       58000.0
# DXB       55590.0

# %% [markdown]
# ### -bonus solution

# %%
from GeoBases import GeoBase

# %%
geoDict=GeoBase(data='ori_por', verbose=False)

# %%
geoDict

# %%
geoDict.keys()
# Out:
# ['AAA',
#  'AAA@1',
#  'AAB',
#  'AAC',
#  'AAC@1',
#  'AAE',
#  'AAE@1',
#  'AAF',
#  'AAF@1',
#  'AAG',
#  'AAG@1',
#  'AAH',
#  'AAH@1',
#  'AAI',
#  'AAI@1',
#  'AAJ',
#  'AAJ@1',
#  'AAJ@2',
#  'AAK',
#  'AAL',
#  'AAL@1',
#  'AAM',
#  'AAN',
#  'AAN@1',
#  'AAO',
#  'AAO@1',
#  'AAP',
#  'AAQ',
#  'AAQ@1',
#  'AAR',
#  'AAR@1',
#  'AAS',
#  'AAT',
#  'AAT@1',
#  'AAU',
#  'AAU@1',
#  'AAV',
#  'AAV@1',
#  'AAX',
#  'AAY',
#  'AAZ',
#  'AAZ@1',
#  'ABA',
#  'ABA@1',
#  'ABB',
#  'ABC',
#  'ABC@1',
#  'ABD',
#  'ABE',
#  'ABE@1',
#  'ABF',
#  'ABG',
#  'ABH',
#  'ABH@1',
#  'ABI',
#  'ABI@1',
#  'ABJ',
#  'ABJ@1',
#  'ABK',
#  'ABL',
#  'ABM',
#  'ABM@1',
#  'ABN',
#  'ABN@1',
#  'ABO',
#  'ABO@1',
#  'ABP',
#  'ABQ',
#  'ABQ@1',
#  'ABR',
#  'ABR@1',
#  'ABS',
#  'ABT',
#  'ABU',
#  'ABU@1',
#  'ABV',
#  'ABW',
#  'ABX',
#  'ABX@1',
#  'ABY',
#  'ABY@1',
#  'ABZ',
#  'ABZ@1',
#  'ACA',
#  'ACB',
#  'ACB@1',
#  'ACC',
#  'ACC@1',
#  'ACD',
#  'ACE',
#  'ACH',
#  'ACH@1',
# ...

# %%
geoDict.get('LHR')['name']
# Out:
# 'London Heathrow Airport'

# %%
newdata = total.reset_index()

# %%
newdata.arr_port[0].strip()
# Out:
# 'LHR'

# %%
geoDict.get(newdata.arr_port[0].strip())['name']
# Out:
# 'London Heathrow Airport'

# %%
newdata['nombre'] = newdata.arr_port.map( lambda x: geoDict.get(x.strip())['name'])

# %%
newdata
# Out:
#    arr_port      pax                                nombre
# 0  LHR       88809.0               London Heathrow Airport
# 1  MCO       70930.0         Orlando International Airport
# 2  LAX       70530.0     Los Angeles International Airport
# 3  LAS       69630.0       Mc Carran International Airport
# 4  JFK       66270.0  John F Kennedy International Airport
# 5  CDG       64490.0             Paris - Charles-de-Gaulle
# 6  BKK       59460.0                          Suvarnabhumi
# 7  MIA       58150.0           Miami International Airport
# 8  SFO       58000.0   San Francisco International Airport
# 9  DXB       55590.0           Dubai International Airport

# %%
total
# Out:
#               pax nombre
# arr_port
# LHR       88809.0
# MCO       70930.0
# LAX       70530.0
# LAS       69630.0
# JFK       66270.0
# CDG       64490.0
# BKK       59460.0
# MIA       58150.0
# SFO       58000.0
# DXB       55590.0

# %%
newdata = newdata.astype({'pax':int})
newdata.to_csv('top_airports.csv', sep='^', index=False)

# %%
! head top_airports.csv
# Out:
# arr_port^pax^nombre
# LHR     ^88809^London Heathrow Airport
# MCO     ^70930^Orlando International Airport
# LAX     ^70530^Los Angeles International Airport
# LAS     ^69630^Mc Carran International Airport
# JFK     ^66270^John F Kennedy International Airport
# CDG     ^64490^Paris - Charles-de-Gaulle
# BKK     ^59460^Suvarnabhumi
# MIA     ^58150^Miami International Airport
# SFO     ^58000^San Francisco International Airport

# %%
from flask import Flask

# %%
app = Flask('My webservice')

@app.route('/hello', methods=['GET'])
def get_hello():
    return "Hello world!!"

# %%
app.run()
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [25/Jan/2019 21:34:44] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Jan/2019 21:34:44] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Jan/2019 21:34:52] "GET /hello HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jan/2019 21:34:52] "GET /favicon.ico HTTP/1.1" 404 -

# %%
app = Flask('My second webservice')

@app.route('/ret_number/<n>', methods=['GET'])
def get_hello(n):
    try:
        numb=int(n)
        return "<div style='background:green'>The number is %d</div>" % numb
    except:
        return "<div style='background:red'>Not a number</div>"

# %%
app.run()
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [25/Jan/2019 21:47:04] "GET /ret_number/45 HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jan/2019 21:47:04] "GET /favicon.ico HTTP/1.1" 404 -

# %%
import pandas as pd

bc = pd.read_csv('top_airports.csv', sep='^')
bc.head(3).to_json()
# Out:
# '{"arr_port":{"0":"LHR     ","1":"MCO     ","2":"LAX     "},"pax":{"0":88809,"1":70930,"2":70530},"nombre":{"0":"London Heathrow Airport","1":"Orlando International Airport","2":"Los Angeles International Airport"}}'

# %%
import pandas as pd

bc = pd.read_csv('top_airports.csv', sep='^')

app = Flask('My second webservice')

@app.route('/ret_number/<n>', methods=['GET'])
def get_hello(n):
    try:
        numb=int(n)


        return bc.head(numb).to_json()
    except:
        return "<div style='background:red'>Not a number</div>"

# %%
app.run()
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [25/Jan/2019 21:54:51] "GET /ret_number/8 HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jan/2019 21:54:51] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Jan/2019 21:54:55] "GET /ret_number/8n HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jan/2019 21:54:55] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Jan/2019 21:54:57] "GET /ret_number/8 HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jan/2019 21:54:57] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Jan/2019 21:55:01] "GET /ret_number/80 HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jan/2019 21:55:01] "GET /favicon.ico HTTP/1.1" 404 -
